# %%
import pandas as pd
df = pd.read_csv('Best Selling Books.csv')
df
# Out:
#                                                    Item  \
# 0     4 PCS Magic Practice Copybook For Kids, Englis...
# 1     Math Concept King - All Formulas And Theorems ...
# 2     SSC Reasoning 7200 TCS MCQ Chapter Wise 4th Ed...
# 3     SSC General Studies 6500 TCS MCQ Chapter Wise ...
# 4     SSC Maths 6800 TCS MCQ Chapter Wise I 4th Edit...
# ...                                                 ...
# 1190       The Indian Contract Act, 1872 EDITION - 2023
# 1191  Junior Teacher Contractual (JTC) For Primary T...
# 1192  Delhi Police Constable Maths 3000 TCS MCQ Chap...
# 1193  UP Police Constable General Studies Chapter Wi...
# 1194                     Heat & Mass Transfer Data Book
#
#                                              type selling_price  \
# 0                              Paperback, Generic           179
# 1               Perfect Binding, Gagan Pratap Sir           189
# 2                Paperback, Pinnacle Publications           499
# ...

# %%
df['selling_price'].max()
# Out:
# '920'

# %%
df = pd.read_csv('weather.csv')
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
weather_data = [
    ('9/10/2023', 32, 6, 'Rain'),
    ('9/11/2023', 35, 7, 'Rain'),
    ('9/12/2023', 28, 2, 'Snow'),
    ('9/13/2023', 24, 7, 'Rain'),
    ('9/14/2023', 32, 4, 'Sunny')
]
df = pd.DataFrame(weather_data, columns=['day', 'temperature', 'windspeed', 'type'])
df
# Out:
#          day  temperature  windspeed   type
# 0  9/10/2023           32          6   Rain
# 1  9/11/2023           35          7   Rain
# 2  9/12/2023           28          2   Snow
# 3  9/13/2023           24          7   Rain
# 4  9/14/2023           32          4  Sunny

# %%
df.tail()
# Out:
#          day  temperature  windspeed   type
# 0  9/10/2023           32          6   Rain
# 1  9/11/2023           35          7   Rain
# 2  9/12/2023           28          2   Snow
# 3  9/13/2023           24          7   Rain
# 4  9/14/2023           32          4  Sunny

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'type'], dtype='object')

# %%
df.day
# Out:
# 0    9/10/2023
# 1    9/11/2023
# 2    9/12/2023
# 3    9/13/2023
# 4    9/14/2023
# Name: day, dtype: object

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     5.000000   5.000000
# mean     30.200000   5.200000
# std       4.266146   2.167948
# min      24.000000   2.000000
# 25%      28.000000   4.000000
# 50%      32.000000   6.000000
# 75%      32.000000   7.000000
# max      35.000000   7.000000

# %%
df
# Out:
#          day  temperature  windspeed   type
# 0  9/10/2023           32          6   Rain
# 1  9/11/2023           35          7   Rain
# 2  9/12/2023           28          2   Snow
# 3  9/13/2023           24          7   Rain
# 4  9/14/2023           32          4  Sunny

# %%
df = pd.read_excel('weatherdata.xlsx')
df
# Out:
#                    day  temperature  windspeed   type
# 0  2023-10-09 00:00:00           32          6   Rain
# 1  2023-11-09 00:00:00           35          7   Rain
# 2  2023-12-09 00:00:00           28          2   Snow
# 3           09/13/2023           24          7   Rain
# 4           09/14/2023           32          4  Sunny

# %%
df.to_csv('wea.csv')

# %%
df = pd.read_excel('weatherdata.xlsx')
df
# Out:
#           day     City  temperature  windspeed    type
# 0  2023-09-10    Delhi           33          4   Rainy
# 1  2023-09-11    Delhi           32          7   Sunny
# 2  2023-09-12    Delhi           35          4   Sunny
# 3  2023-09-13    Delhi           36          8   Sunny
# 4  2023-09-14    Delhi           32          6  Cloudy
# 5  2023-09-15    Delhi           34          7  Cloudy
# 6  2023-09-10   Mumbai           32          2   Rainy
# 7  2023-09-11   Mumbai           35          7   Rainy
# 8  2023-09-12   Mumbai           36          6   Rainy
# 9  2023-09-13   Mumbai           34          8   Sunny
# 10 2023-09-14   Mumbai           33          4   Rainy
# 11 2023-09-15   Mumbai           31          8   Sunny
# 12 2023-09-10  Kolkata           38         11   Rainy
# 13 2023-09-11  Kolkata           29         12   Sunny
# 14 2023-09-12  Kolkata           40          9   Rainy
# 15 2023-09-13  Kolkata           34          8   Rainy
# ...

# %%
group = df.groupby('City')
group

# %%
for city, City_df in group:
    print(city)
    print(City_df)
# Out:
# Delhi
#          day   City  temperature  windspeed    type
# 0 2023-09-10  Delhi           33          4   Rainy
# 1 2023-09-11  Delhi           32          7   Sunny
# 2 2023-09-12  Delhi           35          4   Sunny
# 3 2023-09-13  Delhi           36          8   Sunny
# 4 2023-09-14  Delhi           32          6  Cloudy
# 5 2023-09-15  Delhi           34          7  Cloudy
# Kolkata
#           day     City  temperature  windspeed   type
# 12 2023-09-10  Kolkata           38         11  Rainy
# 13 2023-09-11  Kolkata           29         12  Sunny
# 14 2023-09-12  Kolkata           40          9  Rainy
# 15 2023-09-13  Kolkata           34          8  Rainy
# 16 2023-09-14  Kolkata           37          8  Sunny
# 17 2023-09-15  Kolkata           38          7  Sunny
# Mumbai
#           day    City  temperature  windspeed   type
# 6  2023-09-10  Mumbai           32          2  Rainy
# 7  2023-09-11  Mumbai           35          7  Rainy
# ...

# %%
group.get_group('Delhi')
# Out:
#          day   City  temperature  windspeed    type
# 0 2023-09-10  Delhi           33          4   Rainy
# 1 2023-09-11  Delhi           32          7   Sunny
# 2 2023-09-12  Delhi           35          4   Sunny
# 3 2023-09-13  Delhi           36          8   Sunny
# 4 2023-09-14  Delhi           32          6  Cloudy
# 5 2023-09-15  Delhi           34          7  Cloudy

# %%
print(group.max())
# Out:
#                day  temperature  windspeed   type
# City
# Delhi   2023-09-15           36          8  Sunny
# Kolkata 2023-09-15           40         12  Sunny
# Mumbai  2023-09-15           36          8  Sunny

# %%
print(group.mean())
# Out:
#          temperature  windspeed
# City
# Delhi      33.666667   6.000000
# Kolkata    36.000000   9.166667
# Mumbai     33.500000   5.833333
# /var/folders/70/nn3wz1lj47lg6vtvk9l2j4q80000gn/T/ipykernel_13369/3232203201.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(group.mean())

# %%
print(group.describe())
# Out:
#         temperature                                                       \
#               count       mean       std   min    25%   50%    75%   max
# City
# Delhi           6.0  33.666667  1.632993  32.0  32.25  33.5  34.75  36.0
# Kolkata         6.0  36.000000  3.949684  29.0  34.75  37.5  38.00  40.0
# Mumbai          6.0  33.500000  1.870829  31.0  32.25  33.5  34.75  36.0
#
#         windspeed
#             count      mean       std  min  25%  50%    75%   max
# City
# Delhi         6.0  6.000000  1.673320  4.0  4.5  6.5   7.00   8.0
# Kolkata       6.0  9.166667  1.940790  7.0  8.0  8.5  10.50  12.0
# Mumbai        6.0  5.833333  2.401388  2.0  4.5  6.5   7.75   8.0
